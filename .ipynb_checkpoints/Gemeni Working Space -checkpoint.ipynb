# %%
import pathlib
import textwrap

import google.generativeai as genai
import PIL.Image
from IPython.display import display
from IPython.display import Markdown
import json

# %%
# Or use `os.getenv('GOOGLE_API_KEY')` to fetch an environment variable.
GOOGLE_API_KEY= ''#'AIzaSyA0rakuiHOUDkIlP6Nm_-O182KPaoEm9eI'

genai.configure(api_key=GOOGLE_API_KEY)
model = genai.GenerativeModel('gemini-pro')

# %%
message = "ام محمد اشترت من عندي 3 كيلو فراخ و2 كيلو بانية وحسبتهم ليها ب 650 جنيه "
response = model.generate_content(f"Write a (json (utf-8) ready to save in file) for this next message ${message} fetch message and get products name and total price for all and if there a custom price for each its ok")
response.resolve()

# %%
response.text
# Out:
# '{\n  "message": "$ام محمد اشترت من عندي 3 كيلو فراخ و2 كيلو بانية وحسبتهم ليها ب 650 جنيه",\n  "intent": 4,\n  "products": [\n    {\n      "name": "فراخ",\n      "quantity": 3,\n      "custom_price": null\n    },\n    {\n      "name": "بانية",\n      "quantity": 2,\n      "custom_price": null\n    }\n  ],\n  "total_price": 650\n}'

# %%
model = genai.GenerativeModel('gemini-pro-vision')


img = PIL.Image.open('menu.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x724>

# %%
response = model.generate_content(["Write a (json (utf-8) ready to parse) for all product in the menu", img], stream=True)
response.resolve()
menu_json =response.text
with open('menu.json','a') as menu:
    menu.write(menu_json)

# %%
import json
menu_json =response.text
with open('menu.json','a') as menu:
    menu.write(menu_json)
